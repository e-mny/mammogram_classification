# %%
import pandas as pd

# %%
cbis_csv_calc = "/home/emok/sq58_scratch/emok/Data/CBIS-DDSM_new/calc_case_description_train_set.csv"
cbis_csv_mass = "/home/emok/sq58_scratch/emok/Data/CBIS-DDSM_new/mass_case_description_train_set.csv"
cmmd_csv = "/home/emok/sq58_scratch/emok/Data/CMMD/combined_data.csv"
rsna_csv = "/home/emok/sq58_scratch/emok/Data/RSNA/combined_data_original.csv"
vindr_csv_1 = "/home/emok/sq58_scratch/emok/Data/VinDr/finding_annotations.csv"
vindr_csv_2 = "/home/emok/sq58_scratch/emok/Data/VinDr/combined_data.csv"

# %%
cbis_calc_df = pd.read_csv(cbis_csv_calc)
cbis_calc_df
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
cbis_mass_df = pd.read_csv(cbis_csv_mass)
cbis_mass_df
# Out:
#      patient_id  breast_density left or right breast image view  \
# 0       P_00001               3                 LEFT         CC
# 1       P_00001               3                 LEFT        MLO
# 2       P_00004               3                 LEFT         CC
# 3       P_00004               3                 LEFT        MLO
# 4       P_00004               3                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 1313    P_02033               2                RIGHT        MLO
# 1314    P_02079               2                RIGHT         CC
# 1315    P_02079               2                RIGHT        MLO
# 1316    P_02092               2                 LEFT         CC
# 1317    P_02092               2                 LEFT        MLO
#
#       abnormality id abnormality type                          mass shape  \
# 0                  1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# ...

# %%
cmmd_df = pd.read_csv(cmmd_csv, index_col=0)
cmmd_df
# Out:
#           ID1 LeftRight  Age  number    abnormality classification  \
# 0     D1-0001         R   44       2  calcification         Benign
# 1     D1-0002         L   40       2  calcification         Benign
# 2     D1-0003         L   39       2  calcification         Benign
# 3     D1-0004         L   41       2  calcification         Benign
# 4     D1-0005         R   42       2  calcification         Benign
# ...       ...       ...  ...     ...            ...            ...
# 1867  D2-0745         L   43       2           mass      Malignant
# 1868  D2-0746         R   59       2           mass      Malignant
# 1869  D2-0747         R   53       2           mass      Malignant
# 1870  D2-0748         R   29       2           mass      Malignant
# 1871  D2-0749         L   42       2           mass      Malignant
#
#               subtype  class_label
# 0                 NaN            0
# 1                 NaN            0
# 2                 NaN            0
# ...

# %%
vindr_df_1 = pd.read_csv(vindr_csv_1)
vindr_df_1
# Out:
#                                study_id                         series_id  \
# 0      48575a27b7c992427041a82fa750d3fa  26de4993fa6b8ae50a91c8baf49b92b0
# 1      48575a27b7c992427041a82fa750d3fa  26de4993fa6b8ae50a91c8baf49b92b0
# 2      75e8e48933289d70b407379a564f8594  853b70e7e6f39133497909d9ca4c756d
# 3      75e8e48933289d70b407379a564f8594  853b70e7e6f39133497909d9ca4c756d
# 4      c3487424fee1bdd4515b72dc3fd69813  77619c914263eae44e9099f1ce07192c
# ...                                 ...                               ...
# 20481  f2093a752e6b44df5990f5fd38c99dd2  2b1b2b8f48abab9819c0b3d091e152ee
# 20482  b3c8969cd2accfa4dbb2aece1f7158ab  69d7f07ea04572dad5e5aa62fbcfc4b7
# 20483  b3c8969cd2accfa4dbb2aece1f7158ab  69d7f07ea04572dad5e5aa62fbcfc4b7
# 20484  b3c8969cd2accfa4dbb2aece1f7158ab  69d7f07ea04572dad5e5aa62fbcfc4b7
# 20485  b3c8969cd2accfa4dbb2aece1f7158ab  69d7f07ea04572dad5e5aa62fbcfc4b7
#
#                                image_id laterality view_position  height  \
# ...

# %%
vindr_df_2 = pd.read_csv(vindr_csv_2, index_col=0)
vindr_df_2
# Out:
#                                study_id                         series_id  \
# 0      b8d273e8601f348d3664778dae0e7e0b  b36517b9cbbcfd286a7ae04f643af97a
# 4      8269f5971eaca3e5d3772d1796e6bd7a  d931832a0815df082c085b6e09d20aac
# 8      fa4dcd0f3ba24e86fc8dc25091f7ebd5  a78f4822d806b4f69ba9f0e0c68778b4
# 12     0a0c5108270e814818c1ad002482ce74  ca7f2ada530075dd3cf15df6ee51c835
# 16     ac4975eb788af8b7e15cafca9ac9a1c9  bc183447730d58709da1af503d7c469c
# ...                                 ...                               ...
# 19980  32faa475192319343ddf2d39a34efcbe  0c385b366632459c076f2455bf7bccb0
# 19984  0bfb4e582c69fa4d06d011e637b44fe8  66a2bae2aa8fdf3b875d2d1dec56eaba
# 19988  8db1b8ba11d6d804141f1fa4cf91b614  e26615e35922f3b06ca09a742de0ed8b
# 19992  f2093a752e6b44df5990f5fd38c99dd2  2b1b2b8f48abab9819c0b3d091e152ee
# 19996  b3c8969cd2accfa4dbb2aece1f7158ab  69d7f07ea04572dad5e5aa62fbcfc4b7
#
#       laterality view_position breast_birads  \
# ...

# %%
rsna_df = pd.read_csv(rsna_csv)
rsna_df
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54701        1        9973  1729524723          R  MLO  43.0       0       0
# 54702        1        9989    63473691          L  MLO  60.0       0       0
# 54703        1        9989  1078943060          L   CC  60.0       0       0
# 54704        1        9989   398038886          R  MLO  60.0       0       0
# 54705        1        9989   439796429          R   CC  60.0       0       0
#
# ...

# %%
cbis_calc_df.columns.tolist()
# Out:
# ['patient_id',
#  'breast density',
#  'left or right breast',
#  'image view',
#  'abnormality id',
#  'abnormality type',
#  'calc type',
#  'calc distribution',
#  'assessment',
#  'pathology',
#  'subtlety',
#  'image file path',
#  'cropped image file path',
#  'ROI mask file path']

# %%
cbis_mass_df.columns.tolist()
# Out:
# ['patient_id',
#  'breast_density',
#  'left or right breast',
#  'image view',
#  'abnormality id',
#  'abnormality type',
#  'mass shape',
#  'mass margins',
#  'assessment',
#  'pathology',
#  'subtlety',
#  'image file path',
#  'cropped image file path',
#  'ROI mask file path']

# %%
cmmd_df.columns.tolist()
# Out:
# ['ID1',
#  'LeftRight',
#  'Age',
#  'number',
#  'abnormality',
#  'classification',
#  'subtype',
#  'class_label']

# %%
rsna_df.columns.tolist()
# Out:
# ['site_id',
#  'patient_id',
#  'image_id',
#  'laterality',
#  'view',
#  'age',
#  'cancer',
#  'biopsy',
#  'invasive',
#  'BIRADS',
#  'implant',
#  'density',
#  'machine_id',
#  'difficult_negative_case']

# %%
vindr_df_1.columns.tolist()
# Out:
# ['study_id',
#  'series_id',
#  'image_id',
#  'laterality',
#  'view_position',
#  'height',
#  'width',
#  'breast_birads',
#  'breast_density',
#  'finding_categories',
#  'finding_birads',
#  'xmin',
#  'ymin',
#  'xmax',
#  'ymax',
#  'split']

# %%
vindr_df_2.columns.tolist()
# Out:
# ['study_id',
#  'series_id',
#  'laterality',
#  'view_position',
#  'breast_birads',
#  'image_id',
#  'height',
#  'width',
#  'breast_density',
#  'split',
#  'cancer']

# %%
## Create a table that show what is missing in datasets
property_set = set()
property_set.update(cbis_calc_df.columns.tolist(), cbis_mass_df.columns.tolist(), cmmd_df.columns.tolist(), rsna_df.columns.tolist(), vindr_df_1.columns.tolist(), vindr_df_1.columns.tolist())
property_set
# Out:
# {'Age',
#  'BIRADS',
#  'ID1',
#  'LeftRight',
#  'ROI mask file path',
#  'abnormality',
#  'abnormality id',
#  'abnormality type',
#  'age',
#  'assessment',
#  'biopsy',
#  'breast density',
#  'breast_birads',
#  'breast_density',
#  'calc distribution',
#  'calc type',
#  'cancer',
#  'class_label',
#  'classification',
#  'cropped image file path',
#  'density',
#  'difficult_negative_case',
#  'finding_birads',
#  'finding_categories',
#  'height',
#  'image file path',
#  'image view',
#  'image_id',
#  'implant',
#  'invasive',
#  'laterality',
#  'left or right breast',
#  'machine_id',
#  'mass margins',
#  'mass shape',
#  'number',
#  'pathology',
#  'patient_id',
#  'series_id',
#  'site_id',
#  'split',
#  'study_id',
#  'subtlety',
#  'subtype',
#  'view',
#  'view_position',
#  'width',
#  'xmax',
#  'xmin',
#  'ymax',
#  'ymin'}

# %%
vindr_df_1['finding_categories'].value_counts()
# Out:
# ['No Finding']                                                                                      18232
# ['Mass']                                                                                             1123
# ['Suspicious Calcification']                                                                          402
# ['Focal Asymmetry']                                                                                   232
# ['Architectural Distortion']                                                                           95
# ['Asymmetry']                                                                                          90
# ['Suspicious Calcification', 'Mass']                                                                   82
# ['Suspicious Lymph Node']                                                                              57
# ['Skin Thickening']                                                                                    38
# ...

# %%
# Count occurrences of 'mass' or 'calcification' in 'finding_categories' column
word1 = 'mass'
word2 = 'calcification'

# Using str.contains() to check for occurrences of the words
count_word1 = vindr_df_1['finding_categories'].str.contains(word1, case=False).sum()
count_word2 = vindr_df_1['finding_categories'].str.contains(word2, case=False).sum()

print(f"Occurrences of '{word1}': {count_word1}")
print(f"Occurrences of '{word2}': {count_word2}")
# Out:
# Occurrences of 'mass': 1226
# Occurrences of 'calcification': 543

# %%
vindr_df_1['finding_birads'].value_counts()
# Out:
# BI-RADS 4    995
# BI-RADS 3    893
# BI-RADS 5    241
# Name: finding_birads, dtype: int64

# %%
vindr_df_1['breast_birads'].value_counts()
# Out:
# BI-RADS 1    13406
# BI-RADS 2     4676
# BI-RADS 4     1005
# BI-RADS 3      972
# BI-RADS 5      427
# Name: breast_birads, dtype: int64

# %%
vindr_df_1['breast_density'].value_counts()
# Out:
# DENSITY C    15695
# DENSITY D     2717
# DENSITY B     1973
# DENSITY A      101
# Name: breast_density, dtype: int64
